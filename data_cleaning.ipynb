# %%
import pandas as pd

df=pd.read_csv("glassdoor_jobs.csv")

df
# Out:
#                                              Job Title Salary Estimate  \
# 0                                       Data scientist  ₹436K - ₹480K
# 1                                       Data Scientist  ₹273K - ₹918K
# 2                                Senior Data Scientist  ₹392K - ₹779K
# 3                                         Data Science  ₹300K - ₹833K
# 4                                       Data Scientist            ₹1M
# ..                                                 ...             ...
# 895                           Assistant Data Scientist            ₹1M
# 896                              Senior Data Scientist    ₹941K - ₹1M
# 897                           Machine Learning Trainer    ₹361K - ₹2M
# 898  Data Scientist - Machine Learning/Artificial I...    ₹300K - ₹2M
# 899                                     Data Scientist  ₹289K - ₹652K
#
#      Rating                              Company Name   Location  \
# ...
